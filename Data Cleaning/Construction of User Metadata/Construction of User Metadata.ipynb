# %% [markdown]
# # User Metadata Construction from Browsing Logs
#
# This notebook constructs a **comprehensive user-level metadata table** by combining:
#
# - Raw device-level logs from all schools, including Term 1 (`MG_ files`) and Term 3 (`Browsing History files`).
#
# Official school metadata from `school_category_3.csv`, including school name, gender, and PSLE cutoff group.
#
# Each user is uniquely identified by a `device_name_actual` within a school.

# %% [markdown]
# ---
# ## 0. Imports and Inputs
#
# **Input Variables**
#
# - `RAW_DATA_ROOT` → Path to the folder containing **raw device-level CSV logs** for all schools.
# - `SCHOOL_CATEGORY_FILE` → Path to the official **school metadata CSV** (`school_category_3.csv`).
# - `OUTPUT_FILE_CSV` → Path where the **final user-level metadata CSV** will be saved.
# - `CHUNKSIZE` → Number of rows to read per chunk when processing large CSV files to avoid memory issues (here, 200,000 rows per chunk).

# %%
import pandas as pd
from pathlib import Path
from tqdm import tqdm

# =====================================================
# 0. INPUTS
# =====================================================
RAW_DATA_ROOT = Path("/Users/tdf/Downloads/raw_data")
SCHOOL_CATEGORY_FILE = "/Users/tdf/Downloads/school_category_3.csv"
OUTPUT_FILE_CSV = "/Users/tdf/Downloads/user_metadata.csv"
CHUNKSIZE = 200_000

# %% [markdown]
# ---
# ## 1. Load School Metadata
#
# This step loads and cleans the official school metadata, preparing it for merging with device-level data.
#
# - **Load CSV**
#   - Read `school_category_3.csv` into a DataFrame `school_cat`
#   - Use `low_memory=False` to avoid type inference issues on large files
#   - Use `encoding='utf-8'` to handle special characters correctly
#
# - **Fix mis-encoding for St. Margaret’s Secondary School**
#   - Detect rows where the school name contains the mis-encoded `â€™` and "Margaret"
#   - Replace `â€™` with the correct apostrophe `’`
#
# - ***Map gender to numeric codes**
#   - Convert textual gender labels to numbers for easier processing:
#     - `girls → 1`
#     - `boys → 2`
#     - `co-ed → 99`
#
# - ** Keep only relevant columns**
#   - Keep `name` (school name), `gender` (numeric code), and `psle_al_cutoff_pg3_group`
#   - Rename `psle_al_cutoff_pg3_group` → `sch_psle` for clarity

# %%
# =====================================================
# 1. LOAD SCHOOL METADATA
# =====================================================
school_cat = pd.read_csv(SCHOOL_CATEGORY_FILE, low_memory=False, encoding='utf-8')

# Fix mis-encoding for St. Margaret’s
mask_margaret = school_cat['name'].str.contains('â€™', regex=False) & \
                school_cat['name'].str.contains('Margaret', regex=False)
school_cat.loc[mask_margaret, 'name'] = school_cat.loc[mask_margaret, 'name'].str.replace('â€™', '’', regex=False)

# Map gender to numbers
gender_map = {'girls': 1, 'boys': 2, 'co-ed': 99}
school_cat['gender'] = school_cat['gender'].map(gender_map)

# Keep only required columns
school_cat = school_cat[['name', 'gender', 'psle_al_cutoff_pg3_group']]
school_cat.rename(columns={'psle_al_cutoff_pg3_group': 'sch_psle'}, inplace=True)

# %% [markdown]
# ---
# ## 2. Collect Term 1 & Term 3 Device Presence
#
# This step scans all raw device-level CSV files to build **sets of unique devices** present in Term 1 and Term 3.
#
# - ** Identify school folders**
#   - List all subfolders in `RAW_DATA_ROOT`, where each folder corresponds to a school.
#
# - **Iterate through CSV files**
#   - For each school folder, find all `.csv` files.
#   - Determine the **term type** based on the filename:
#     - Filenames containing `"MG"` → **Term 1**
#     - Filenames containing `"Browsing History"` → **Term 3**
#     - Skip other files
#
# - **Read device names in chunks**
#   - Use `pd.read_csv` with `chunksize=CHUNKSIZE` to handle large files efficiently
#   - Extract the `device_name_actual` column, drop missing values, and get unique devices
#
# - **Update device sets**
#   - Add Term 1 devices to `term1_devices` set
#   - Add Term 3 devices to `term3_devices` set
#
# - **Error handling**
#   - If a CSV fails to read, skip it and print a warning

# %%
# =====================================================
# 2. SCAN ALL SCHOOL FILES TO BUILD TERM 1 & TERM 3 DEVICE SETS
# =====================================================
term1_devices = set()
term3_devices = set()

school_folders = [f for f in RAW_DATA_ROOT.iterdir() if f.is_dir()]

for school_folder in tqdm(school_folders, desc="Processing schools"):
    csv_files = list(school_folder.glob("*.csv"))
    for csv_file in tqdm(csv_files, desc=f"{school_folder.name}", leave=False):
        filename_lower = csv_file.name.lower()
        if "mg" in filename_lower:             # Term 1
            file_type = "term1"
        elif "browsing history" in filename_lower:  # Term 3
            file_type = "term3"
        else:
            continue

        try:
            for chunk in pd.read_csv(csv_file, usecols=['device_name_actual'],
                                     dtype={'device_name_actual': str}, chunksize=CHUNKSIZE):
                devices = chunk['device_name_actual'].dropna().unique()
                if file_type == "term1":
                    term1_devices.update(devices)
                else:
                    term3_devices.update(devices)
        except Exception as e:
            print(f"Skipping {csv_file.name} due to error: {e}")

print(f"Term 1 devices: {len(term1_devices)}, Term 3 devices: {len(term3_devices)}")
# Out:
# Processing schools:   0%|                                | 0/48 [00:00<?, ?it/s]
# North Vista Secondary:   0%|                              | 0/4 [00:00<?, ?it/s]
# North Vista Secondary:  25%|█████▌                | 1/4 [00:01<00:04,  1.36s/it]
# North Vista Secondary:  50%|███████████           | 2/4 [00:03<00:03,  1.73s/it]
# North Vista Secondary:  75%|████████████████▌     | 3/4 [00:04<00:01,  1.44s/it]
# North Vista Secondary: 100%|██████████████████████| 4/4 [00:05<00:00,  1.26s/it]
# Processing schools:   2%|▌                       | 1/48 [00:05<04:15,  5.44s/it]
# Raffles Girls' School:   0%|                              | 0/4 [00:00<?, ?it/s]
# Raffles Girls' School:  25%|█████▌                | 1/4 [00:01<00:04,  1.66s/it]
# Raffles Girls' School:  50%|███████████           | 2/4 [00:02<00:02,  1.46s/it]
# Raffles Girls' School:  75%|████████████████▌     | 3/4 [00:04<00:01,  1.48s/it]
# Raffles Girls' School: 100%|██████████████████████| 4/4 [00:05<00:00,  1.33s/it]
# Processing schools:   4%|█                       | 2/48 [00:11<04:14,  5.53s/it]
# Dunman High School:   0%|                                 | 0/5 [00:00<?, ?it/s]
# Dunman High School:  20%|█████                    | 1/5 [00:01<00:07,  1.89s/it]
# Dunman High School:  40%|██████████               | 2/5 [00:03<00:05,  1.92s/it]
# Dunman High School:  60%|███████████████          | 3/5 [00:05<00:03,  1.60s/it]
# Dunman High School:  80%|████████████████████     | 4/5 [00:06<00:01,  1.46s/it]
# Dunman High School: 100%|█████████████████████████| 5/5 [00:07<00:00,  1.33s/it]
# Processing schools:   6%|█▌                      | 3/48 [00:18<04:46,  6.38s/it]
# Fuhua Secondary:   0%|                                    | 0/4 [00:00<?, ?it/s]
# Fuhua Secondary:  25%|███████                     | 1/4 [00:00<00:01,  1.64it/s]
# Fuhua Secondary:  50%|██████████████              | 2/4 [00:00<00:00,  2.25it/s]
# Fuhua Secondary:  75%|█████████████████████       | 3/4 [00:01<00:00,  2.29it/s]
# Fuhua Secondary: 100%|████████████████████████████| 4/4 [00:01<00:00,  2.09it/s]
# Processing schools:   8%|██                      | 4/48 [00:20<03:23,  4.61s/it]
# Methodist Girls' School (Secondary):   0%|                | 0/4 [00:00<?, ?it/s]
# Methodist Girls' School (Secondary):  25%|██      | 1/4 [00:00<00:01,  2.04it/s]
# Methodist Girls' School (Secondary):  50%|████    | 2/4 [00:01<00:01,  1.32it/s]
# Methodist Girls' School (Secondary):  75%|██████  | 3/4 [00:02<00:00,  1.25it/s]
# Methodist Girls' School (Secondary): 100%|████████| 4/4 [00:03<00:00,  1.27it/s]
# Processing schools:  10%|██▌                     | 5/48 [00:23<02:54,  4.05s/it]
# CHIJ St Joseph’s Convent :   0%|                          | 0/5 [00:00<?, ?it/s]
# CHIJ St Joseph’s Convent :  20%|███▌              | 1/5 [00:02<00:08,  2.22s/it]
# CHIJ St Joseph’s Convent :  40%|███████▏          | 2/5 [00:03<00:05,  1.89s/it]
# CHIJ St Joseph’s Convent :  60%|██████████▊       | 3/5 [00:05<00:03,  1.60s/it]
# CHIJ St Joseph’s Convent :  80%|██████████████▍   | 4/5 [00:07<00:01,  1.88s/it]
# CHIJ St Joseph’s Convent : 100%|██████████████████| 5/5 [00:09<00:00,  1.77s/it]
# Processing schools:  12%|███                     | 6/48 [00:32<04:01,  5.75s/it]
# Assumption English Sch:   0%|                             | 0/4 [00:00<?, ?it/s]
# Assumption English Sch:  25%|█████▎               | 1/4 [00:00<00:02,  1.35it/s]
# Assumption English Sch:  50%|██████████▌          | 2/4 [00:01<00:01,  1.72it/s]
# Assumption English Sch:  75%|███████████████▊     | 3/4 [00:02<00:00,  1.31it/s]
# Assumption English Sch: 100%|█████████████████████| 4/4 [00:03<00:00,  1.22it/s]
# Processing schools:  15%|███▌                    | 7/48 [00:35<03:20,  4.88s/it]
# Nan Chiau High School:   0%|                              | 0/4 [00:00<?, ?it/s]
# Nan Chiau High School:  25%|█████▌                | 1/4 [00:01<00:05,  1.71s/it]
# Nan Chiau High School:  50%|███████████           | 2/4 [00:03<00:03,  1.51s/it]
# Nan Chiau High School:  75%|████████████████▌     | 3/4 [00:04<00:01,  1.46s/it]
# Nan Chiau High School: 100%|██████████████████████| 4/4 [00:06<00:00,  1.69s/it]
# Processing schools:  17%|████                    | 8/48 [00:42<03:36,  5.41s/it]
# Whitley Secondary:   0%|                                  | 0/4 [00:00<?, ?it/s]
# Whitley Secondary:  25%|██████▌                   | 1/4 [00:00<00:01,  1.81it/s]
# Whitley Secondary:  50%|█████████████             | 2/4 [00:01<00:01,  1.27it/s]
# Whitley Secondary:  75%|███████████████████▌      | 3/4 [00:02<00:00,  1.37it/s]
# Whitley Secondary: 100%|██████████████████████████| 4/4 [00:03<00:00,  1.15it/s]
# Processing schools:  19%|████▌                   | 9/48 [00:45<03:04,  4.73s/it]
# Yishun Town Secondary:   0%|                              | 0/4 [00:00<?, ?it/s]
# Yishun Town Secondary:  25%|█████▌                | 1/4 [00:01<00:03,  1.17s/it]
# Yishun Town Secondary:  50%|███████████           | 2/4 [00:01<00:01,  1.14it/s]
# Yishun Town Secondary:  75%|████████████████▌     | 3/4 [00:02<00:00,  1.27it/s]
# Yishun Town Secondary: 100%|██████████████████████| 4/4 [00:03<00:00,  1.13it/s]
# Processing schools:  21%|████▊                  | 10/48 [00:48<02:46,  4.37s/it]
# Xinmin Secondary:   0%|                                   | 0/4 [00:00<?, ?it/s]
# Xinmin Secondary:  25%|██████▊                    | 1/4 [00:01<00:05,  1.69s/it]
# Xinmin Secondary:  50%|█████████████▌             | 2/4 [00:03<00:03,  1.62s/it]
# Xinmin Secondary:  75%|████████████████████▎      | 3/4 [00:05<00:01,  1.74s/it]
# Xinmin Secondary: 100%|███████████████████████████| 4/4 [00:06<00:00,  1.56s/it]
# Processing schools:  23%|█████▎                 | 11/48 [00:55<03:05,  5.01s/it]
# Mayflower Secondary:   0%|                                | 0/4 [00:00<?, ?it/s]
# Mayflower Secondary:  25%|██████                  | 1/4 [00:01<00:03,  1.09s/it]
# Mayflower Secondary:  50%|████████████            | 2/4 [00:01<00:01,  1.04it/s]
# Mayflower Secondary:  75%|██████████████████      | 3/4 [00:02<00:00,  1.18it/s]
# Mayflower Secondary: 100%|████████████████████████| 4/4 [00:03<00:00,  1.05it/s]
# Processing schools:  25%|█████▊                 | 12/48 [00:59<02:47,  4.64s/it]
# Hai Sing Catholic School:   0%|                           | 0/4 [00:00<?, ?it/s]
# Hai Sing Catholic School:  25%|████▊              | 1/4 [00:01<00:05,  1.85s/it]
# Hai Sing Catholic School:  50%|█████████▌         | 2/4 [00:03<00:03,  1.58s/it]
# Hai Sing Catholic School:  75%|██████████████▎    | 3/4 [00:04<00:01,  1.56s/it]
# Hai Sing Catholic School: 100%|███████████████████| 4/4 [00:06<00:00,  1.77s/it]
# Processing schools:  27%|██████▏                | 13/48 [01:06<03:06,  5.32s/it]
# Chua Chu Kang Secondary:   0%|                            | 0/6 [00:00<?, ?it/s]
# Chua Chu Kang Secondary:  17%|███▎                | 1/6 [00:01<00:05,  1.06s/it]
# Chua Chu Kang Secondary:  33%|██████▋             | 2/6 [00:02<00:05,  1.45s/it]
# Chua Chu Kang Secondary:  50%|██████████          | 3/6 [00:04<00:04,  1.35s/it]
# Chua Chu Kang Secondary:  67%|█████████████▎      | 4/6 [00:05<00:02,  1.44s/it]
# Chua Chu Kang Secondary:  83%|████████████████▋   | 5/6 [00:06<00:01,  1.34s/it]
# Chua Chu Kang Secondary: 100%|████████████████████| 6/6 [00:08<00:00,  1.32s/it]
# Processing schools:  29%|██████▋                | 14/48 [01:14<03:28,  6.13s/it]
# Seng Kang Secondary:   0%|                                | 0/4 [00:00<?, ?it/s]
# Seng Kang Secondary:  25%|██████                  | 1/4 [00:01<00:03,  1.11s/it]
# Seng Kang Secondary:  50%|████████████            | 2/4 [00:01<00:01,  1.03it/s]
# Seng Kang Secondary:  75%|██████████████████      | 3/4 [00:02<00:00,  1.05it/s]
# Seng Kang Secondary: 100%|████████████████████████| 4/4 [00:03<00:00,  1.14it/s]
# Processing schools:  31%|███████▏               | 15/48 [01:17<02:57,  5.39s/it]
# Bendemeer Secondary:   0%|                                | 0/4 [00:00<?, ?it/s]
# Bendemeer Secondary:  25%|██████                  | 1/4 [00:00<00:02,  1.06it/s]
# Bendemeer Secondary:  50%|████████████            | 2/4 [00:01<00:02,  1.00s/it]
# Bendemeer Secondary:  75%|██████████████████      | 3/4 [00:03<00:01,  1.21s/it]
# Bendemeer Secondary: 100%|████████████████████████| 4/4 [00:04<00:00,  1.24s/it]
# Processing schools:  33%|███████▋               | 16/48 [01:22<02:46,  5.19s/it]
# Bowen Secondary:   0%|                                    | 0/4 [00:00<?, ?it/s]
# Bowen Secondary:  25%|███████                     | 1/4 [00:01<00:03,  1.06s/it]
# Bowen Secondary:  50%|██████████████              | 2/4 [00:02<00:02,  1.30s/it]
# Bowen Secondary:  75%|█████████████████████       | 3/4 [00:03<00:01,  1.30s/it]
# Bowen Secondary: 100%|████████████████████████████| 4/4 [00:05<00:00,  1.41s/it]
# Processing schools:  35%|████████▏              | 17/48 [01:27<02:43,  5.26s/it]
# Orchid Park Secondary:   0%|                              | 0/4 [00:00<?, ?it/s]
# Orchid Park Secondary:  25%|█████▌                | 1/4 [00:01<00:04,  1.34s/it]
# Orchid Park Secondary:  50%|███████████           | 2/4 [00:02<00:02,  1.03s/it]
# Orchid Park Secondary:  75%|████████████████▌     | 3/4 [00:02<00:00,  1.08it/s]
# Orchid Park Secondary: 100%|██████████████████████| 4/4 [00:04<00:00,  1.01it/s]
# Processing schools:  38%|████████▋              | 18/48 [01:31<02:26,  4.90s/it]
# Manjusri Secondary:   0%|                                 | 0/4 [00:00<?, ?it/s]
# Manjusri Secondary:  25%|██████▎                  | 1/4 [00:00<00:02,  1.17it/s]
# Manjusri Secondary:  50%|████████████▌            | 2/4 [00:02<00:02,  1.07s/it]
# Manjusri Secondary:  75%|██████████████████▊      | 3/4 [00:03<00:01,  1.24s/it]
# Manjusri Secondary: 100%|█████████████████████████| 4/4 [00:04<00:00,  1.12s/it]
# Processing schools:  40%|█████████              | 19/48 [01:36<02:18,  4.76s/it]
# Boon Lay Secondary:   0%|                                 | 0/4 [00:00<?, ?it/s]
# Boon Lay Secondary:  25%|██████▎                  | 1/4 [00:00<00:01,  2.56it/s]
# Boon Lay Secondary:  50%|████████████▌            | 2/4 [00:00<00:00,  3.71it/s]
# Boon Lay Secondary:  75%|██████████████████▊      | 3/4 [00:00<00:00,  3.59it/s]
# Boon Lay Secondary: 100%|█████████████████████████| 4/4 [00:01<00:00,  4.16it/s]
# Processing schools:  42%|█████████▌             | 20/48 [01:37<01:42,  3.65s/it]
# Bukit View Secondary:   0%|                               | 0/4 [00:00<?, ?it/s]
# Bukit View Secondary:  25%|█████▊                 | 1/4 [00:01<00:03,  1.03s/it]
# Bukit View Secondary:  50%|███████████▌           | 2/4 [00:02<00:02,  1.20s/it]
# Bukit View Secondary:  75%|█████████████████▎     | 3/4 [00:03<00:01,  1.27s/it]
# Bukit View Secondary: 100%|███████████████████████| 4/4 [00:05<00:00,  1.37s/it]
# Processing schools:  44%|██████████             | 21/48 [01:42<01:51,  4.12s/it]
# Canberra Secondary:   0%|                                 | 0/4 [00:00<?, ?it/s]
# Canberra Secondary:  25%|██████▎                  | 1/4 [00:00<00:00,  4.71it/s]
# Canberra Secondary:  50%|████████████▌            | 2/4 [00:00<00:00,  3.81it/s]
# Canberra Secondary:  75%|██████████████████▊      | 3/4 [00:00<00:00,  3.45it/s]
# Canberra Secondary: 100%|█████████████████████████| 4/4 [00:01<00:00,  3.23it/s]
# Processing schools:  46%|██████████▌            | 22/48 [01:43<01:24,  3.23s/it]
# Catholic High School:   0%|                               | 0/4 [00:00<?, ?it/s]
# Catholic High School:  25%|█████▊                 | 1/4 [00:01<00:04,  1.60s/it]
# Catholic High School:  50%|███████████▌           | 2/4 [00:03<00:03,  1.71s/it]
# Catholic High School:  75%|█████████████████▎     | 3/4 [00:05<00:01,  1.73s/it]
# Catholic High School: 100%|███████████████████████| 4/4 [00:07<00:00,  1.85s/it]
# Processing schools:  48%|███████████            | 23/48 [01:50<01:50,  4.42s/it]
# Christ Church Secondary:   0%|                            | 0/4 [00:00<?, ?it/s]
# Christ Church Secondary:  25%|█████               | 1/4 [00:01<00:04,  1.42s/it]
# Christ Church Secondary:  50%|██████████          | 2/4 [00:02<00:02,  1.16s/it]
# Christ Church Secondary:  75%|███████████████     | 3/4 [00:03<00:01,  1.04s/it]
# Christ Church Secondary: 100%|████████████████████| 4/4 [00:04<00:00,  1.13s/it]
# Processing schools:  50%|███████████▌           | 24/48 [01:55<01:47,  4.46s/it]
# CHIJ St Nicholas Girls_ School (Secondary):   0%|         | 0/4 [00:00<?, ?it/s]
# CHIJ St Nicholas Girls_ School (Secondary):  25%|▎| 1/4 [00:00<00:02,  1.46it/s]
# CHIJ St Nicholas Girls_ School (Secondary):  50%|▌| 2/4 [00:01<00:01,  1.18it/s]
# CHIJ St Nicholas Girls_ School (Secondary):  75%|▊| 3/4 [00:02<00:01,  1.02s/it]
# CHIJ St Nicholas Girls_ School (Secondary): 100%|█| 4/4 [00:03<00:00,  1.06s/it]
# Processing schools:  52%|███████████▉           | 25/48 [01:59<01:39,  4.32s/it]
# Woodgrove Secondary School:   0%|                         | 0/6 [00:00<?, ?it/s]
# Woodgrove Secondary School:  17%|██▊              | 1/6 [00:00<00:04,  1.01it/s]
# Woodgrove Secondary School:  33%|█████▋           | 2/6 [00:02<00:05,  1.27s/it]
# Woodgrove Secondary School:  50%|████████▌        | 3/6 [00:03<00:03,  1.21s/it]
# Woodgrove Secondary School:  67%|███████████▎     | 4/6 [00:04<00:02,  1.25s/it]
# Woodgrove Secondary School:  83%|██████████████▏  | 5/6 [00:05<00:00,  1.09it/s]
# Woodgrove Secondary School: 100%|█████████████████| 6/6 [00:07<00:00,  1.23s/it]
# Processing schools:  54%|████████████▍          | 26/48 [02:06<01:53,  5.15s/it]
# Edgefield Secondary:   0%|                                | 0/4 [00:00<?, ?it/s]
# Edgefield Secondary:  25%|██████                  | 1/4 [00:00<00:01,  2.55it/s]
# Edgefield Secondary:  50%|████████████            | 2/4 [00:00<00:00,  2.32it/s]
# Edgefield Secondary:  75%|██████████████████      | 3/4 [00:01<00:00,  2.83it/s]
# Edgefield Secondary: 100%|████████████████████████| 4/4 [00:01<00:00,  2.32it/s]
# Processing schools:  56%|████████████▉          | 27/48 [02:08<01:26,  4.11s/it]
# Kuo Chuan Presbyterian:   0%|                             | 0/4 [00:00<?, ?it/s]
# Kuo Chuan Presbyterian:  25%|█████▎               | 1/4 [00:00<00:00,  3.89it/s]
# Kuo Chuan Presbyterian:  50%|██████████▌          | 2/4 [00:00<00:00,  2.64it/s]
# Kuo Chuan Presbyterian:  75%|███████████████▊     | 3/4 [00:01<00:00,  2.30it/s]
# Kuo Chuan Presbyterian: 100%|█████████████████████| 4/4 [00:01<00:00,  2.10it/s]
# Processing schools:  58%|█████████████▍         | 28/48 [02:10<01:08,  3.40s/it]
# Montfort Secondary:   0%|                                 | 0/4 [00:00<?, ?it/s]
# Montfort Secondary:  25%|██████▎                  | 1/4 [00:01<00:03,  1.08s/it]
# Montfort Secondary:  50%|████████████▌            | 2/4 [00:02<00:02,  1.22s/it]
# Montfort Secondary:  75%|██████████████████▊      | 3/4 [00:03<00:01,  1.37s/it]
# Montfort Secondary: 100%|█████████████████████████| 4/4 [00:05<00:00,  1.28s/it]
# Processing schools:  60%|█████████████▉         | 29/48 [02:15<01:14,  3.91s/it]
# Greendale Secondary:   0%|                                | 0/6 [00:00<?, ?it/s]
# Greendale Secondary:  17%|████                    | 1/6 [00:00<00:04,  1.01it/s]
# Greendale Secondary:  33%|████████                | 2/6 [00:02<00:04,  1.16s/it]
# Greendale Secondary:  50%|████████████            | 3/6 [00:03<00:03,  1.29s/it]
# Greendale Secondary:  67%|████████████████        | 4/6 [00:04<00:02,  1.17s/it]
# Greendale Secondary:  83%|████████████████████    | 5/6 [00:05<00:01,  1.14s/it]
# Greendale Secondary: 100%|████████████████████████| 6/6 [00:06<00:00,  1.06s/it]
# Processing schools:  62%|██████████████▍        | 30/48 [02:21<01:25,  4.75s/it]
# Swiss Cottage Secondary:   0%|                            | 0/4 [00:00<?, ?it/s]
# Swiss Cottage Secondary:  25%|█████               | 1/4 [00:00<00:01,  1.52it/s]
# Swiss Cottage Secondary:  50%|██████████          | 2/4 [00:01<00:01,  1.86it/s]
# Swiss Cottage Secondary:  75%|███████████████     | 3/4 [00:01<00:00,  2.15it/s]
# Swiss Cottage Secondary: 100%|████████████████████| 4/4 [00:02<00:00,  1.95it/s]
# Processing schools:  65%|██████████████▊        | 31/48 [02:23<01:07,  3.95s/it]
# Evergreen Secondary:   0%|                                | 0/4 [00:00<?, ?it/s]
# Evergreen Secondary:  25%|██████                  | 1/4 [00:00<00:01,  1.72it/s]
# Evergreen Secondary:  50%|████████████            | 2/4 [00:01<00:01,  1.66it/s]
# Evergreen Secondary:  75%|██████████████████      | 3/4 [00:01<00:00,  1.89it/s]
# Evergreen Secondary: 100%|████████████████████████| 4/4 [00:02<00:00,  2.16it/s]
# Processing schools:  67%|███████████████▎       | 32/48 [02:25<00:53,  3.36s/it]
# Outram Secondary:   0%|                                   | 0/4 [00:00<?, ?it/s]
# Outram Secondary:  25%|██████▊                    | 1/4 [00:00<00:01,  2.03it/s]
# Outram Secondary:  50%|█████████████▌             | 2/4 [00:00<00:00,  2.17it/s]
# Outram Secondary:  75%|████████████████████▎      | 3/4 [00:01<00:00,  2.71it/s]
# Outram Secondary: 100%|███████████████████████████| 4/4 [00:01<00:00,  2.83it/s]
# Processing schools:  69%|███████████████▊       | 33/48 [02:27<00:42,  2.81s/it]
# Singapore Sports School:   0%|                            | 0/4 [00:00<?, ?it/s]
# Singapore Sports School:  25%|█████               | 1/4 [00:00<00:01,  2.94it/s]
# Singapore Sports School:  50%|██████████          | 2/4 [00:00<00:00,  2.28it/s]
# Singapore Sports School:  75%|███████████████     | 3/4 [00:01<00:00,  2.14it/s]
# Singapore Sports School: 100%|████████████████████| 4/4 [00:01<00:00,  2.18it/s]
# Processing schools:  71%|████████████████▎      | 34/48 [02:29<00:35,  2.51s/it]
# Northland Secondary:   0%|                                | 0/4 [00:00<?, ?it/s]
# Northland Secondary:  25%|██████                  | 1/4 [00:01<00:04,  1.35s/it]
# Northland Secondary:  50%|████████████            | 2/4 [00:02<00:02,  1.23s/it]
# Northland Secondary:  75%|██████████████████      | 3/4 [00:03<00:00,  1.00it/s]
# Northland Secondary: 100%|████████████████████████| 4/4 [00:03<00:00,  1.13it/s]
# Processing schools:  73%|████████████████▊      | 35/48 [02:33<00:38,  2.94s/it]
# St Margaret's Secondary:   0%|                            | 0/7 [00:00<?, ?it/s]
# St Margaret's Secondary:  14%|██▊                 | 1/7 [00:01<00:10,  1.83s/it]
# St Margaret's Secondary:  29%|█████▋              | 2/7 [00:03<00:08,  1.63s/it]
# St Margaret's Secondary:  43%|████████▌           | 3/7 [00:04<00:04,  1.24s/it]
# St Margaret's Secondary:  57%|███████████▍        | 4/7 [00:05<00:03,  1.25s/it]
# St Margaret's Secondary:  71%|██████████████▎     | 5/7 [00:06<00:02,  1.25s/it]
# St Margaret's Secondary:  86%|█████████████████▏  | 6/7 [00:07<00:01,  1.25s/it]
# St Margaret's Secondary: 100%|████████████████████| 7/7 [00:08<00:00,  1.17s/it]
# Processing schools:  75%|█████████████████▎     | 36/48 [02:42<00:56,  4.72s/it]
# Woodlands Secondary:   0%|                                | 0/4 [00:00<?, ?it/s]
# Woodlands Secondary:  25%|██████                  | 1/4 [00:00<00:02,  1.34it/s]
# Woodlands Secondary:  50%|████████████            | 2/4 [00:01<00:01,  1.57it/s]
# Woodlands Secondary:  75%|██████████████████      | 3/4 [00:02<00:00,  1.30it/s]
# Woodlands Secondary: 100%|████████████████████████| 4/4 [00:02<00:00,  1.31it/s]
# Processing schools:  77%|█████████████████▋     | 37/48 [02:45<00:46,  4.20s/it]
# Yio Chu Kang Secondary:   0%|                             | 0/4 [00:00<?, ?it/s]
# Yio Chu Kang Secondary:  25%|█████▎               | 1/4 [00:00<00:01,  2.06it/s]
# Yio Chu Kang Secondary:  50%|██████████▌          | 2/4 [00:00<00:00,  2.49it/s]
# Yio Chu Kang Secondary:  75%|███████████████▊     | 3/4 [00:01<00:00,  2.11it/s]
# Yio Chu Kang Secondary: 100%|█████████████████████| 4/4 [00:01<00:00,  2.29it/s]
# Processing schools:  79%|██████████████████▏    | 38/48 [02:46<00:34,  3.47s/it]
# Hillgrove Secondary:   0%|                                | 0/4 [00:00<?, ?it/s]
# Hillgrove Secondary:  25%|██████                  | 1/4 [00:00<00:01,  1.89it/s]
# Hillgrove Secondary:  50%|████████████            | 2/4 [00:00<00:00,  2.41it/s]
# Hillgrove Secondary:  75%|██████████████████      | 3/4 [00:01<00:00,  2.32it/s]
# Hillgrove Secondary: 100%|████████████████████████| 4/4 [00:01<00:00,  2.55it/s]
# Processing schools:  81%|██████████████████▋    | 39/48 [02:48<00:26,  2.92s/it]
# Chung Cheng High (Main):   0%|                            | 0/6 [00:00<?, ?it/s]
# Chung Cheng High (Main):  17%|███▎                | 1/6 [00:01<00:06,  1.31s/it]
# Chung Cheng High (Main):  33%|██████▋             | 2/6 [00:02<00:05,  1.48s/it]
# Chung Cheng High (Main):  50%|██████████          | 3/6 [00:03<00:03,  1.28s/it]
# Chung Cheng High (Main):  67%|█████████████▎      | 4/6 [00:04<00:02,  1.15s/it]
# Chung Cheng High (Main):  83%|████████████████▋   | 5/6 [00:05<00:01,  1.09s/it]
# Chung Cheng High (Main): 100%|████████████████████| 6/6 [00:07<00:00,  1.31s/it]
# Processing schools:  83%|███████████████████▏   | 40/48 [02:56<00:34,  4.33s/it]
# Ngee Ann Secondary:   0%|                                 | 0/4 [00:00<?, ?it/s]
# Ngee Ann Secondary:  25%|██████▎                  | 1/4 [00:00<00:01,  2.21it/s]
# Ngee Ann Secondary:  50%|████████████▌            | 2/4 [00:00<00:00,  3.36it/s]
# Ngee Ann Secondary:  75%|██████████████████▊      | 3/4 [00:00<00:00,  3.24it/s]
# Ngee Ann Secondary: 100%|█████████████████████████| 4/4 [00:01<00:00,  2.86it/s]
# Processing schools:  85%|███████████████████▋   | 41/48 [02:57<00:24,  3.45s/it]
# Guangyang Secondary:   0%|                                | 0/4 [00:00<?, ?it/s]
# Guangyang Secondary:  25%|██████                  | 1/4 [00:00<00:01,  1.81it/s]
# Guangyang Secondary:  50%|████████████            | 2/4 [00:01<00:01,  1.85it/s]
# Guangyang Secondary:  75%|██████████████████      | 3/4 [00:01<00:00,  1.64it/s]
# Guangyang Secondary: 100%|████████████████████████| 4/4 [00:02<00:00,  1.34it/s]
# Processing schools:  88%|████████████████████▏  | 42/48 [03:00<00:19,  3.24s/it]
# Chung Cheng High School (Yishun):   0%|                   | 0/4 [00:00<?, ?it/s]
# Chung Cheng High School (Yishun):  25%|██▊        | 1/4 [00:00<00:01,  1.72it/s]
# Chung Cheng High School (Yishun):  50%|█████▌     | 2/4 [00:01<00:01,  1.46it/s]
# Chung Cheng High School (Yishun):  75%|████████▎  | 3/4 [00:02<00:00,  1.25it/s]
# Chung Cheng High School (Yishun): 100%|███████████| 4/4 [00:03<00:00,  1.03it/s]
# Processing schools:  90%|████████████████████▌  | 43/48 [03:03<00:16,  3.32s/it]
# Maris Stella High School:   0%|                           | 0/4 [00:00<?, ?it/s]
# Maris Stella High School:  25%|████▊              | 1/4 [00:01<00:03,  1.18s/it]
# Maris Stella High School:  50%|█████████▌         | 2/4 [00:02<00:02,  1.21s/it]
# Maris Stella High School:  75%|██████████████▎    | 3/4 [00:03<00:01,  1.34s/it]
# Maris Stella High School: 100%|███████████████████| 4/4 [00:05<00:00,  1.40s/it]
# Processing schools:  92%|█████████████████████  | 44/48 [03:09<00:15,  3.94s/it]
# Yishun Secondary:   0%|                                   | 0/4 [00:00<?, ?it/s]
# Yishun Secondary:  25%|██████▊                    | 1/4 [00:00<00:02,  1.42it/s]
# Yishun Secondary:  50%|█████████████▌             | 2/4 [00:01<00:01,  1.61it/s]
# Yishun Secondary:  75%|████████████████████▎      | 3/4 [00:02<00:00,  1.40it/s]
# Yishun Secondary: 100%|███████████████████████████| 4/4 [00:02<00:00,  1.63it/s]
# Processing schools:  94%|█████████████████████▌ | 45/48 [03:11<00:10,  3.52s/it]
# Pasir Ris Secondary:   0%|                                | 0/4 [00:00<?, ?it/s]
# Pasir Ris Secondary:  25%|██████                  | 1/4 [00:01<00:03,  1.10s/it]
# Pasir Ris Secondary:  50%|████████████            | 2/4 [00:01<00:01,  1.08it/s]
# Pasir Ris Secondary:  75%|██████████████████      | 3/4 [00:02<00:00,  1.00it/s]
# Pasir Ris Secondary: 100%|████████████████████████| 4/4 [00:03<00:00,  1.02it/s]
# Processing schools:  96%|██████████████████████ | 46/48 [03:15<00:07,  3.65s/it]
# Broadrick Secondary:   0%|                                | 0/4 [00:00<?, ?it/s]
# Broadrick Secondary:  25%|██████                  | 1/4 [00:00<00:02,  1.30it/s]
# Broadrick Secondary:  50%|████████████            | 2/4 [00:01<00:01,  1.33it/s]
# Broadrick Secondary:  75%|██████████████████      | 3/4 [00:02<00:00,  1.17it/s]
# Broadrick Secondary: 100%|████████████████████████| 4/4 [00:03<00:00,  1.03it/s]
# Processing schools:  98%|██████████████████████▌| 47/48 [03:19<00:03,  3.65s/it]
# Kent Ridge Secondary:   0%|                               | 0/4 [00:00<?, ?it/s]
# Kent Ridge Secondary:  25%|█████▊                 | 1/4 [00:01<00:05,  1.67s/it]
# Kent Ridge Secondary:  50%|███████████▌           | 2/4 [00:03<00:03,  1.54s/it]
# Kent Ridge Secondary:  75%|█████████████████▎     | 3/4 [00:04<00:01,  1.37s/it]
# Kent Ridge Secondary: 100%|███████████████████████| 4/4 [00:05<00:00,  1.23s/it]
# Processing schools: 100%|███████████████████████| 48/48 [03:24<00:00,  4.26s/it]
# Term 1 devices: 36281, Term 3 devices: 48594

# %% [markdown]
# ---
# ## 3. Build User Metadata
#
# This step constructs a **user-level metadata table** by combining raw device logs with official school information. Each user is uniquely identified by their `device_name_actual` and school.
#
# - **Load school metadata**
#   - Read `school_category_3.csv` into `school_cat`
#   - Fix encoding issues (e.g., St. Margaret’s) to ensure school names are correct
#   - Normalize school names for safe lookup (`name_norm`)
#   - Map gender to numbers:
#     - Girls → `1`
#     - Boys → `2`
#     - Co-ed → `99`
#
# - **Manual school name mapping**
#   - Maps raw folder names in `raw_data` to official school names
#   - Ensures that folder names match metadata for correct merging
#
# - **Iterate over school folders**
#   - For each school folder:
#     - Lookup the official school name
#     - Fetch school info: `gender` and `sch_psle` from metadata
#
# - **Read device CSVs in chunks**
#   - Iterate all `.csv` files in the folder
#   - Use `chunksize=CHUNKSIZE` for memory efficiency
#   - Extract unique `device_name_actual` entries
#
# - **Assign student level**
#   - **Level 1** → devices present in Term 3 but **not** in Term 1 (new Secondary 1 students)
#   - **Level 2** → all other devices (Secondary 2–5 students)
#
# - **Build user records**
#   - Append a dictionary for each device containing:
#     - `device_name_actual`
#     - `school_name_official`
#     - `gender`
#     - `sch_psle`
#     - `level`
#
# - **Convert to DataFrame**
#   - Combine all user records into `users_df` for further processing and export

# %%
# =====================================================
# 3. BUILD USER METADATA (corrected)
# =====================================================
import pandas as pd
from pathlib import Path
from tqdm import tqdm

# Load school metadata
school_cat = pd.read_csv("/Users/tdf/Downloads/school_category_3.csv", encoding='utf-8', low_memory=False)

# Fix St. Margaret's mis-encoding
mask_margaret = school_cat['name'].str.contains('â€™', regex=False) & \
                school_cat['name'].str.contains('Margaret', regex=False)
school_cat.loc[mask_margaret, 'name'] = school_cat.loc[mask_margaret, 'name'].str.replace('â€™', '’', regex=False)

# Normalize school names for safe lookup
school_cat['name_norm'] = school_cat['name'].str.strip().str.lower()

# Gender mapping: girls=1, boys=2, co-ed=99
gender_map = {'girls': 1, 'boys': 2, 'co-ed': 99}

# Manual mapping: raw folder names -> official school names
manual_school_mapping = {
    "assumption english sch": "Assumption English School",
    "bendemeer secondary": "Bendemeer Secondary School",
    "boon lay secondary": "Boon Lay Secondary School",
    "bowen secondary": "Bowen Secondary School",
    "broadrick secondary": "Broadrick Secondary School",
    "bukit view secondary": "Bukit View Secondary School",
    "canberra secondary": "Canberra Secondary School",
    "catholic high school": "Catholic High School (Secondary)",
    "chij st joseph’s convent": "CHIJ St. Joseph's Convent",
    "chij st nicholas girls_ school (secondary)": "CHIJ St. Nicholas Girls' School (Secondary)",
    "christ church secondary": "Christ Church Secondary School",
    "chua chu kang secondary": "Chua Chu Kang Secondary School",
    "chung cheng high (main)": "Chung Cheng High School (Main)",
    "chung cheng high school (yishun)": "Chung Cheng High School (Yishun)",
    "dunman high school": "Dunman High School",
    "edgefield secondary": "Edgefield Secondary School",
    "evergreen secondary": "Evergreen Secondary School",
    "fuhua secondary": "Fuhua Secondary School",
    "greendale secondary": "Greendale Secondary School",
    "guangyang secondary": "Guangyang Secondary School",
    "hai sing catholic school": "Hai Sing Catholic School",
    "hillgrove secondary": "Hillgrove Secondary School",
    "kent ridge secondary": "Kent Ridge Secondary School",
    "kuo chuan presbyterian": "Kuo Chuan Presbyterian Secondary School",
    "manjusri secondary": "Manjusri Secondary School",
    "maris stella high school": "Maris Stella High School (Secondary)",
    "mayflower secondary": "Mayflower Secondary School",
    "methodist girls' school (secondary)": "Methodist Girls' School (Secondary)",
    "montfort secondary": "Montfort Secondary School",
    "nan chiau high school": "Nan Chiau High School",
    "ngee ann secondary": "Ngee Ann Secondary School",
    "north vista secondary": "North Vista Secondary School",
    "northland secondary": "Northland Secondary School",
    "orchid park secondary": "Orchid Park Secondary School",
    "outram secondary": "Outram Secondary School",
    "pasir ris secondary": "Pasir Ris Secondary School",
    "raffles girls' school": "Raffles Girls' School",
    "seng kang secondary": "Seng Kang Secondary School",
    "singapore sports school": "Singapore Sports School",
    "st margaret's secondary": "St. Margaret’s Secondary School",
    "swiss cottage secondary": "Swiss Cottage Secondary School",
    "whitley secondary": "Whitley Secondary School",
    "woodgrove secondary school": "Woodgrove Secondary School",
    "woodlands secondary": "Woodlands Secondary School",
    "xinmin secondary": "Xinmin Secondary School",
    "yio chu kang secondary": "Yio Chu Kang Secondary School",
    "yishun secondary": "Yishun Secondary School",
    "yishun town secondary": "Yishun Town Secondary School"
}

# Set raw data root
RAW_DATA_ROOT = Path("/Users/tdf/Downloads/raw_data")
school_folders = [f for f in RAW_DATA_ROOT.iterdir() if f.is_dir()]

# Normalize term1/term3 device lists
term1_devices_norm = set(d.strip().lower() for d in term1_devices)
term3_devices_norm = set(d.strip().lower() for d in term3_devices)

all_users = []

# Iterate over all school folders
for school_folder in tqdm(school_folders, desc="Building user metadata"):
    raw_name = school_folder.name.strip().lower()
    school_name_official = manual_school_mapping.get(raw_name)
    
    if school_name_official is None:
        print(f"Warning: {school_folder.name} not found in mapping. Skipping.")
        continue
    
    # Fetch school info
    school_info = school_cat[school_cat['name_norm'] == school_name_official.strip().lower()].iloc[0]
    gender = gender_map[school_info['gender'].strip().lower()]
    sch_psle = school_info['psle_al_cutoff_pg3_group']

    # Iterate CSV files for the school
    csv_files = list(school_folder.glob("*.csv"))
    for csv_file in csv_files:
        try:
            for chunk in pd.read_csv(
                csv_file,
                usecols=['device_name_actual'],
                dtype={'device_name_actual': str},
                chunksize=CHUNKSIZE,
                low_memory=False
            ):
                for device in chunk['device_name_actual'].dropna().unique():
                    device_norm = device.strip().lower()
                    
                    # Assign level
                    if device_norm in term3_devices_norm and device_norm not in term1_devices_norm:
                        level = 1  # Secondary 1
                    else:
                        level = 2  # Secondary 2-5
                    
                    all_users.append({
                        'device_name_actual': device,
                        'school_name_official': school_name_official,
                        'gender': gender,
                        'sch_psle': sch_psle,
                        'level': level
                    })
        except Exception as e:
            print(f"Skipping {csv_file.name} due to error: {e}")

# Convert to DataFrame
users_df = pd.DataFrame(all_users)
# Out:
# Building user metadata: 100%|███████████████████| 48/48 [03:25<00:00,  4.29s/it]

# %% [markdown]
# ---
# ## 4. Final Checks and Export
#
# This step performs **quality control** on the constructed user metadata before exporting:
#
# - **Check for missing values**
#   - Use `isna().sum()` to count any missing entries in the key columns:
#     - `school_name_official` → the official school name of the device
#     - `gender` → numeric gender label (1=Girls, 2=Boys, 99=Co-ed)
#     - `sch_psle` → school PSLE cutoff group
#     - `level` → student level (1=Secondary 1, 2=Secondary 2–5)
#   - Ensures that the dataset is complete and ready for downstream analysis

# %%
# =====================================================
# 4. FINAL CHECKS AND EXPORT
# =====================================================
print("\nMissing values summary:")
print(users_df[['school_name_official','gender','sch_psle','level']].isna().sum())
# Out:
# Missing values summary:
# school_name_official    0
# gender                  0
# sch_psle                0
# level                   0
# dtype: int64

# %% [markdown]
# ---
# ## 5. Export User Metadata
#
# This step **saves the final user-level metadata** to a CSV file:
#
# - **Export to CSV**
#   - `users_df.to_csv(OUTPUT_FILE_CSV, index=False)` writes the dataset to the specified path
#   - `index=False` ensures the row index is not included in the CSV

# %%
# =====================================================
# 5. EXPORT
# =====================================================
OUTPUT_FILE_CSV = "/Users/tdf/Downloads/user_metadata.csv"
users_df.to_csv(OUTPUT_FILE_CSV, index=False)

print(f"\nTotal users collected: {len(users_df)}")
print(f"User metadata CSV created: {OUTPUT_FILE_CSV}")
# Out:
# Total users collected: 1075262
# User metadata CSV created: /Users/tdf/Downloads/user_metadata.csv
