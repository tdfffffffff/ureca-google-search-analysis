# %% [markdown]
# # User Metadata Construction from Browsing Logs
#
# This notebook constructs a **clean, user-level metadata table** by combining:
# - A large browsing masterlist (`masterlist_df`)
# - Raw device-level logs (Term 1 vs Term 3)
# - Official school metadata (`school_category_3.csv`)
#
# Each user is uniquely identified by a **(device_name_actual, school)** pair.
# The final output is a consolidated dataset suitable for downstream analysis.

# %% [markdown]
# ---
# ## 1. Load Masterlist Dataset
#
# We begin by loading the master browsing dataset, which contains:
# - Device identifiers
# - School identifiers
# - Timestamps, URLs, and derived linguistic features
#
# This dataset represents **event-level browsing records**, not users.

# %%
import pandas as pd 
masterlist_df = pd.read_csv("/Users/tdf/Downloads/filtered_df_for_specific_broad_final.csv")
masterlist_df.head()
# Out:
# /var/folders/_s/jbptsrkj25b9n_k1fq0pw42h0000gn/T/ipykernel_29306/2836213083.py:2: DtypeWarning: Columns (4,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   masterlist_df = pd.read_csv("/Users/tdf/Downloads/filtered_df_for_specific_broad_final.csv")
#              school_name                 created_at  \
# 0  orchid_park_secondary  2023-07-09 21:06:21+00:00
# 1  orchid_park_secondary  2023-07-09 21:21:00+00:00
# 2  orchid_park_secondary  2023-07-09 21:21:54+00:00
# 3  orchid_park_secondary  2023-07-09 21:24:07+00:00
# 4  orchid_park_secondary  2023-07-09 21:24:34+00:00
#
#                                                  uri  device_name_actual  \
# 0  https://www.google.com/search?q=wy&rlz=1CAGWKK...               36719
# 1  https://www.google.com/search?rlz=1CAGWKK_enSG...               36719
# 2  https://www.google.com/search?q=hospital+betwe...               36719
# 3  https://www.google.com/search?q=hospital+after...               36719
# 4  https://www.google.com/search?q=hospital+after...               36719
#
#   was_allowed  profile_custom                          search_q  \
# 0        True             0.0                                wy
# 1        True             0.0    hospital between 1959 and 1970
# 2        True             0.0  hospital between 1960s and 1970s
# 3        True             0.0               hospital after 1965
# 4        True             0.0  hospital after 1965 in singapore
#
#   has_safe_active  is_navigational  q_episode  ...  topic  hypernym_distance  \
# 0            True            False        1.0  ...      1               9.00
# 1            True            False        2.0  ...     73               7.50
# 2           False            False        2.0  ...      0               6.50
# 3           False            False        2.0  ...     73               7.50
# 4           False            False        2.0  ...     46               7.75
#
#    hypernym_specificity  episode_hypernym_specificity_ratio  \
# 0              specific                                 1.0
# 1              specific                                 1.0
# 2              specific                                 1.0
# 3              specific                                 1.0
# 4              specific                                 1.0
#
#    avg_text_concreteness  brysbaert_specificity  \
# 0                   0.00               abstract
# 1                   4.64               concrete
# 2                   4.64               concrete
# 3                   4.64               concrete
# 4                   4.64               concrete
#
#    brysbaert_concreteness_for_episode  episode_brysbaert_specificity_ratio  \
# 0                                0.00                                  0.0
# 1                                4.64                                  1.0
# 2                                4.64                                  1.0
# 3                                4.64                                  1.0
# 4                                4.64                                  1.0
#
#    Category_nouns  Category_noun_words
# 0           False                   []
# 1           False                   []
# 2           False                   []
# 3           False                   []
# 4           False                   []
#
# [5 rows x 44 columns]

# %% [markdown]
# ---
# ## 2. Inspect School Naming Conventions (Masterlist)
#
# The `school_name` field in the masterlist uses **machine-friendly identifiers**
# (eg. `orchid_park_secondary`, `st_margaret's_secondary`).
#
# We enumerate all unique school identifiers to:
# - Understand coverage
# - Prepare a mapping to official school names

# %%
for name in masterlist_df['school_name'].unique():
    print(name)
# Out:
# orchid_park_secondary
# methodist_girls'_school
# chung_cheng_high_yishun
# mayflower_secondary
# xinmin_secondary
# choa_chu_kang_secondary
# bukit_view_secondary
# bendemeer_secondary
# raffles_girls'
# fuhua_secondary
# catholic_high
# chij_st_joseph's_convent
# kent_ridge_secondary
# chung_cheng_high_main
# christ_church_secondary
# sports_school
# whitley_secondary
# chij_st_nicholas
# hai_sing_catholic_school
# dunman_high
# woodlands_secondary
# nan_chiau_high_school
# northland_secondary
# kuo_chuan_presbyterian_school
# st_margaret's_secondary
# woodgrove_secondary
# broadrick_secondary
# yishun_secondary
# north_vista_secondary
# yishun_town_secondary
# hillgrove_secondary
# guangyang_secondary
# swiss_cottage_secondary
# manjusri_secondary
# boonlay_secondary
# assumption_english_secondary
# yio_chu_kang_secondary
# bowen_secondary
# evergreen_secondary
# pasir_ris_secondary
# outram_secondary
# maris_stella
# ngee_ann_secondary
# montfort_secondary
# greendale_secondary
# edgefield_secondary
# seng_kang_secondary

# %% [markdown]
# ---
# ## 3. Load Official School Metadata
#
# The `school_category_3.csv` file contains **official MOE school metadata**, including:
# - School name (human-readable)
# - Gender type
# - PSLE AL cutoff group
#
# This dataset will later be merged using **standardised school names**.

# %%
SCHOOL_CATEGORY_FILE = pd.read_csv('/Users/tdf/Downloads/school_category_3.csv')
SCHOOL_CATEGORY_FILE.head()
# Out:
#   category type   zone cluster                        name  \
# 0       GA  Sec   West      W6   Assumption English School
# 1        G  Sec  South      S5  Bendemeer Secondary School
# 2        G  Sec   West      W3   Boon Lay Secondary School
# 3        G  Sec  North      N1      Bowen Secondary School
# 4        G  Sec   East      E5  Broadrick Secondary School
#
#                    principal                          email      baseline  \
# 0  Mr Kwok Chin Poh Benjamin   Benjamin_KWOK@schools.gov.sg  Survey (alt)
# 1          Ms Foo Sheue Feng       Foo Sheue Feng (SCHOOLS)        Survey
# 2          Mr Inderjit Singh  Inderjit_SINGH@schools.gov.sg        Survey
# 3          Mr Loh Chih Hui\n    LOH_CHIH_HUI@SCHOOLS.GOV.SG  Survey (alt)
# 4            Mr Ng Tiong Nam         Tiong Nam NG (SCHOOLS)  Survey (alt)
#
#                        name2      os touchscreen? keyboard stylus gender  \
# 0     Assumption English Sch  Chrome            Y        Y      Y  co-ed
# 1  Bendemeer Secondary - 539  Chrome            Y        Y      Y  co-ed
# 2   Boon Lay Secondary - 644     iOS            Y        Y      Y  co-ed
# 3      Bowen Secondary - 855  Chrome            Y        Y      Y  co-ed
# 4  Broadrick Secondary - 688  Chrome            Y        Y      Y  co-ed
#
#    psle_al_cutoff_pg3  psle_al_cutoff_pg3_group  ses
# 0                  22                         4  NaN
# 1                  22                         4  5.0
# 2                  22                         4  4.0
# 3                  16                         3  3.0
# 4                  22                         4  NaN

# %%
for name in SCHOOL_CATEGORY_FILE['name'].unique():
    print(name)
# Out:
# Assumption English School
# Bendemeer Secondary School
# Boon Lay Secondary School
# Bowen Secondary School
# Broadrick Secondary School
# Bukit View Secondary School
# Canberra Secondary School
# Catholic High School (Secondary)
# CHIJ St. Joseph's Convent
# CHIJ St. Nicholas Girls' School (Secondary)
# Christ Church Secondary School
# Chua Chu Kang Secondary School
# Chung Cheng High School (Main)
# Chung Cheng High School (Yishun)
# Dunman High School
# Edgefield Secondary School
# Evergreen Secondary School
# Fuhua Secondary School
# Greendale Secondary School
# Guangyang Secondary School
# Hai Sing Catholic School
# Hillgrove Secondary School
# Kent Ridge Secondary School
# Kuo Chuan Presbyterian Secondary School
# Manjusri Secondary School
# Maris Stella High School (Secondary)
# Mayflower Secondary School
# Methodist Girls' School (Secondary)
# Montfort Secondary School
# Nan Chiau High School
# Ngee Ann Secondary School
# North Vista Secondary School
# Northland Secondary School
# Orchid Park Secondary School
# Outram Secondary School
# Pasir Ris Secondary School
# Raffles Girls' School
# Seng Kang Secondary School
# Singapore Sports School
# St. Margaretâ€™s Secondary School
# Swiss Cottage Secondary School
# Whitley Secondary School
# Woodgrove Secondary School
# Woodlands Secondary School
# Xinmin Secondary School
# Yio Chu Kang Secondary School
# Yishun Secondary School
# Yishun Town Secondary School

# %% [markdown]
# ---
# ## 4. Identify and Handle Encoding Issues in School Names
#
# During inspection of the official school metadata (`school_category_3.csv`), we identify
# a character encoding issue affecting **St. Margaret’s Secondary School**:
#
# - The apostrophe (`’`) appears as the mis-encoded sequence **`â€™`** in the CSV file.
# - This is a known UTF-8 / Windows-1252 encoding mismatch.
#
# To preserve data integrity, this issue is handled **surgically**:
# - Only rows containing both **“Margaret”** and **`â€™`** are corrected.
# - All other school names remain unchanged.
#
# This ensures that encoding fixes do **not affect unrelated schools**.

# %% [markdown]
# ---
# ## 5. Construct the User Universe
#
# We define a user as a unique:
#
# > **(device_name_actual, school_name)** pair
#
# This design choice ensures that:
# - Devices reused across different schools are treated as distinct users
# - All downstream joins and classifications remain school-specific
#
# The same `device_name_actual` can appear across multiple schools, but each occurrence is treated as a distinct user.
#
# The resulting dataset (`users_df`) represents the **complete universe of users**
# derived from the masterlist.
#
# ---
# ## 6. Map School Identifiers to Official School Names
#
# The masterlist uses machine-readable school identifiers
# (e.g. `st_margaret's_secondary`, `orchid_park_secondary`).
#
# To enable a clean merge with official school metadata, we map these identifiers to
# **conventional, human-readable school names** that match those in
# `school_category_3.csv`.
#
# Example:
# - `st_margaret's_secondary` → `St. Margaret’s Secondary School`
#
# This standardised field is stored as:
# - **`school_name_official`**
#
# ---
# ## 7. Determine Device Presence by Academic Term
#
# To infer students’ academic levels, we determine whether each device appears in:
#
# - **Term 1 data**
#   - Data files with filenames starting with **`MG_`**
# - **Term 3 data**
#   - Data files with filenames starting with **`Browsing history`**
#
# For each school folder:
# - Device identifiers are extracted in chunks for memory efficiency
# - Two global sets are built:
#   - `term1_devices`
#   - `term3_devices`
#
# This allows efficient membership checks for each user.
#
# ---
# ## 8. Define and Assign Student Level (`level`)
#
# We define a new variable **`level`** to represent students’ academic level:
#
# ### Definition
# - **`level = 1`**
#   Device appears in **Term 3 data but NOT Term 1 data**
#   → These are **Secondary 1 students**, who only received their devices in Term 3
#
# - **`level = 2`**
#   All other users
#   → These represent **Secondary 2–5 students**
#
# ### Implementation
# - All users are initialized with `level = 2`
# - Users whose devices appear only in Term 3 are reassigned to `level = 1`
#
#
# This inference is done at the **device-school level**, not globally.
#
# ---
# ## 9. Load School Metadata and Define New Variables
#
# We now merge official school metadata from `school_category_3.csv`
# to define additional user-level variables.
#
# The following variables are constructed:
#
# ### Gender (`gender`)
#
# The `gender` variable is derived from the **`gender`** column in
# `school_category_3.csv`, based on school type:
#
# - **Girls’ school** → `gender = 1`
# - **Boys’ school** → `gender = 2`
# - **Co-educational school** → `gender = 99`
#
# The value `99` is used for co-ed schools because the biological sex
# of individual students is unknown.
#
# ### PSLE Cutoff Group (`sch_psle`)
#
# The `sch_psle` variable is derived from the
# **`psle_al_cutoff_pg3_group`** column in `school_category_3.csv`.
#
# This represents the school’s PSLE AL cutoff group.
#
# Example:
# - Devices from **Assumption English School** are assigned
#   `sch_psle = 4`, as the school’s cutoff group is 4 in the metadata file.
#
# ---
# ## 10. Merge User Data with School Metadata
#
# The user universe is merged with official school metadata using:
#
# - `school_name_official` (from the masterlist mapping)
# - `name` (from `school_category_3.csv`)
#
# This merge appends:
# - `gender`
# - `sch_psle`
#
# to each **(device_name_actual, school)** pair.
#
# After merging:
# - Redundant columns are removed
# - Variable names are standardized for clarity
#
# ---
# ## 11. Final Data Quality Checks
#
# We perform final validation checks to ensure data completeness:
#
# - Missing values in:
#   - `school_name_official`
#   - `gender`
#   - `sch_psle`
#   - `level`
# - Verification that encoding corrections succeeded
# - Confirmation that all users were successfully classified
#
# Any remaining missing values indicate schools that require
# manual inspection or additional mapping.
#
# ---
# ## 12. Export Final User Metadata
#
# The final dataset includes:
# - `device_name_actual`
# - Official school name
# - Gender code
# - PSLE cutoff group
# - Inferred academic level
#
# Outputs are saved as both:
# - Excel (`.xlsx`) for inspection
# - CSV (`.csv`) for analysis pipelines

# %%
import pandas as pd
from pathlib import Path
from tqdm import tqdm

# =====================================================
# 0. INPUTS
# =====================================================
MASTERLIST_FILE = "/Users/tdf/Downloads/filtered_df_for_specific_broad_final.csv"
RAW_DATA_ROOT = Path("/Users/tdf/Downloads/raw_data")
SCHOOL_CATEGORY_FILE = "/Users/tdf/Downloads/school_category_3.csv"
OUTPUT_FILE_XLSX = "/Users/tdf/Downloads/user_metadata.xlsx"
OUTPUT_FILE_CSV = "/Users/tdf/Downloads/user_metadata.csv"

CHUNKSIZE = 200_000

# =====================================================
# 1. LOAD MASTERLIST AND BUILD USER UNIVERSE
# =====================================================
masterlist_df = pd.read_csv(MASTERLIST_FILE, low_memory=False)

# Each (device_name_actual, school_name) is unique
users_df = masterlist_df[['device_name_actual', 'school_name']].drop_duplicates().reset_index(drop=True)
print(f"Unique user-school pairs in masterlist: {len(users_df)}")

# =====================================================
# 2. SCHOOL MAPPING: masterlist -> conventional official name
# =====================================================
school_mapping = {
    'orchid_park_secondary': 'Orchid Park Secondary School',
    'methodist_girls\'_school': 'Methodist Girls\' School (Secondary)',
    'chung_cheng_high_yishun': 'Chung Cheng High School (Yishun)',
    'mayflower_secondary': 'Mayflower Secondary School',
    'xinmin_secondary': 'Xinmin Secondary School',
    'choa_chu_kang_secondary': 'Chua Chu Kang Secondary School',
    'bukit_view_secondary': 'Bukit View Secondary School',
    'bendemeer_secondary': 'Bendemeer Secondary School',
    'raffles_girls\'': 'Raffles Girls\' School',
    'fuhua_secondary': 'Fuhua Secondary School',
    'catholic_high': 'Catholic High School (Secondary)',
    "chij_st_joseph's_convent": "CHIJ St. Joseph's Convent",
    'kent_ridge_secondary': 'Kent Ridge Secondary School',
    'chung_cheng_high_main': 'Chung Cheng High School (Main)',
    'christ_church_secondary': 'Christ Church Secondary School',
    'sports_school': 'Singapore Sports School',
    'whitley_secondary': 'Whitley Secondary School',
    'chij_st_nicholas': "CHIJ St. Nicholas Girls' School (Secondary)",
    'hai_sing_catholic_school': 'Hai Sing Catholic School',
    'dunman_high': 'Dunman High School',
    'woodlands_secondary': 'Woodlands Secondary School',
    'nan_chiau_high_school': 'Nan Chiau High School',
    'northland_secondary': 'Northland Secondary School',
    'kuo_chuan_presbyterian_school': 'Kuo Chuan Presbyterian Secondary School',
    'st_margaret\'s_secondary': 'St. Margaret’s Secondary School',  # target
    'woodgrove_secondary': 'Woodgrove Secondary School',
    'broadrick_secondary': 'Broadrick Secondary School',
    'yishun_secondary': 'Yishun Secondary School',
    'north_vista_secondary': 'North Vista Secondary School',
    'yishun_town_secondary': 'Yishun Town Secondary School',
    'hillgrove_secondary': 'Hillgrove Secondary School',
    'guangyang_secondary': 'Guangyang Secondary School',
    'swiss_cottage_secondary': 'Swiss Cottage Secondary School',
    'manjusri_secondary': 'Manjusri Secondary School',
    'boonlay_secondary': 'Boon Lay Secondary School',
    'assumption_english_secondary': 'Assumption English School',
    'yio_chu_kang_secondary': 'Yio Chu Kang Secondary School',
    'bowen_secondary': 'Bowen Secondary School',
    'evergreen_secondary': 'Evergreen Secondary School',
    'pasir_ris_secondary': 'Pasir Ris Secondary School',
    'outram_secondary': 'Outram Secondary School',
    'maris_stella': 'Maris Stella High School (Secondary)',
    'ngee_ann_secondary': 'Ngee Ann Secondary School',
    'montfort_secondary': 'Montfort Secondary School',
    'greendale_secondary': 'Greendale Secondary School',
    'edgefield_secondary': 'Edgefield Secondary School',
    'seng_kang_secondary': 'Seng Kang Secondary School',
}

# Map masterlist_df school_name -> conventional official name
users_df['school_name_official'] = users_df['school_name'].map(school_mapping)

# =====================================================
# 3. COLLECT TERM 1 & TERM 3 DEVICE PRESENCE
# =====================================================
term1_devices = set()
term3_devices = set()

school_folders = [f for f in RAW_DATA_ROOT.iterdir() if f.is_dir()]

for school_folder in tqdm(school_folders, desc="Schools"):
    csv_files = list(school_folder.glob("*.csv"))
    for csv_file in tqdm(csv_files, desc=f"{school_folder.name}", leave=False):
        filename_lower = csv_file.name.lower()
        if "mg" in filename_lower:
            file_type = "term1"
        elif "browsing history" in filename_lower:
            file_type = "term3"
        else:
            continue

        try:
            for chunk in pd.read_csv(csv_file, usecols=['device_name_actual'], chunksize=CHUNKSIZE):
                devices = chunk['device_name_actual'].dropna().unique()
                if file_type == "term1":
                    term1_devices.update(devices)
                else:
                    term3_devices.update(devices)
        except Exception as e:
            print(f"Skipping {csv_file.name} due to error: {e}")

print("\nFinished scanning raw data.")
print(f"Devices in Term 1: {len(term1_devices)}, Term 3: {len(term3_devices)}")

# =====================================================
# 4. ASSIGN LEVEL
# =====================================================
users_df['level'] = 2
users_df.loc[
    users_df['device_name_actual'].isin(term3_devices) &
    ~users_df['device_name_actual'].isin(term1_devices),
    'level'
] = 1

# =====================================================
# 5. LOAD SCHOOL METADATA AND MERGE
# =====================================================
school_cat = pd.read_csv(SCHOOL_CATEGORY_FILE, low_memory=False)

# Only fix mis-encoding for St. Margaret’s
mask_margaret = school_cat['name'].str.contains('â€™', regex=False) & \
                school_cat['name'].str.contains('Margaret', regex=False)
school_cat.loc[mask_margaret, 'name'] = school_cat.loc[mask_margaret, 'name'].str.replace('â€™', '’', regex=False)

# Map gender to numbers
gender_map = {'girls': 1, 'boys': 2, 'co-ed': 99}
school_cat['gender'] = school_cat['gender'].map(gender_map)

# Merge on official names
users_df = users_df.merge(
    school_cat[['name', 'gender', 'psle_al_cutoff_pg3_group']],
    left_on='school_name_official',
    right_on='name',
    how='left'
)

# Clean final columns
users_df.rename(columns={'psle_al_cutoff_pg3_group': 'sch_psle'}, inplace=True)
users_df.drop(columns=['name'], inplace=True)

# =====================================================
# 6. FINAL CHECKS
# =====================================================
print("\nMissing values summary:")
print(users_df[['school_name_official','gender','sch_psle','level']].isna().sum())

# =====================================================
# 7. EXPORT
# =====================================================
final_user_metadata = users_df[['device_name_actual','school_name_official','gender','sch_psle','level']]
final_user_metadata.to_excel(OUTPUT_FILE_XLSX, index=False)
final_user_metadata.to_csv(OUTPUT_FILE_CSV, index=False)

print(f"\nUser metadata files created: {OUTPUT_FILE_XLSX}, {OUTPUT_FILE_CSV}")
# Out:
# Unique user-school pairs in masterlist: 4989
# Schools:   0%|                                           | 0/47 [00:00<?, ?it/s]
# orchid_park_secondary:   0%|                              | 0/4 [00:00<?, ?it/s]
# orchid_park_secondary:  25%|█████▌                | 1/4 [00:01<00:03,  1.15s/it]
# orchid_park_secondary:  50%|███████████           | 2/4 [00:01<00:01,  1.14it/s]
# orchid_park_secondary:  75%|████████████████▌     | 3/4 [00:02<00:00,  1.27it/s]
# orchid_park_secondary: 100%|██████████████████████| 4/4 [00:03<00:00,  1.17it/s]
# Schools:   2%|▋                                  | 1/47 [00:03<02:40,  3.48s/it]
# methodist_girls'_school:   0%|                            | 0/4 [00:00<?, ?it/s]
# methodist_girls'_school:  25%|█████               | 1/4 [00:00<00:01,  2.50it/s]
# methodist_girls'_school:  50%|██████████          | 2/4 [00:01<00:01,  1.54it/s]
# methodist_girls'_school:  75%|███████████████     | 3/4 [00:01<00:00,  1.42it/s]
# methodist_girls'_school: 100%|████████████████████| 4/4 [00:02<00:00,  1.44it/s]
# Schools:   4%|█▍                                 | 2/47 [00:06<02:15,  3.01s/it]
# chung_cheng_high_yishun:   0%|                            | 0/4 [00:00<?, ?it/s]
# chung_cheng_high_yishun:  25%|█████               | 1/4 [00:00<00:01,  1.96it/s]
# chung_cheng_high_yishun:  50%|██████████          | 2/4 [00:01<00:01,  1.66it/s]
# chung_cheng_high_yishun:  75%|███████████████     | 3/4 [00:02<00:00,  1.41it/s]
# chung_cheng_high_yishun: 100%|████████████████████| 4/4 [00:03<00:00,  1.17it/s]
# Schools:   6%|██▏                                | 3/47 [00:09<02:14,  3.05s/it]
# mayflower_secondary:   0%|                                | 0/4 [00:00<?, ?it/s]
# mayflower_secondary:  25%|██████                  | 1/4 [00:00<00:02,  1.06it/s]
# mayflower_secondary:  50%|████████████            | 2/4 [00:01<00:01,  1.19it/s]
# mayflower_secondary:  75%|██████████████████      | 3/4 [00:02<00:00,  1.30it/s]
# mayflower_secondary: 100%|████████████████████████| 4/4 [00:03<00:00,  1.18it/s]
# Schools:   9%|██▉                                | 4/47 [00:12<02:16,  3.18s/it]
# xinmin_secondary:   0%|                                   | 0/4 [00:00<?, ?it/s]
# xinmin_secondary:  25%|██████▊                    | 1/4 [00:01<00:04,  1.43s/it]
# xinmin_secondary:  50%|█████████████▌             | 2/4 [00:02<00:02,  1.43s/it]
# xinmin_secondary:  75%|████████████████████▎      | 3/4 [00:05<00:01,  1.87s/it]
# xinmin_secondary: 100%|███████████████████████████| 4/4 [00:06<00:00,  1.65s/it]
# Schools:  11%|███▋                               | 5/47 [00:19<03:04,  4.40s/it]
# choa_chu_kang_secondary:   0%|                            | 0/6 [00:00<?, ?it/s]
# choa_chu_kang_secondary:  17%|███▎                | 1/6 [00:01<00:05,  1.00s/it]
# choa_chu_kang_secondary:  33%|██████▋             | 2/6 [00:02<00:05,  1.30s/it]
# choa_chu_kang_secondary:  50%|██████████          | 3/6 [00:03<00:03,  1.23s/it]
# choa_chu_kang_secondary:  67%|█████████████▎      | 4/6 [00:04<00:02,  1.27s/it]
# choa_chu_kang_secondary:  83%|████████████████▋   | 5/6 [00:06<00:01,  1.19s/it]
# choa_chu_kang_secondary: 100%|████████████████████| 6/6 [00:07<00:00,  1.16s/it]
# Schools:  13%|████▍                              | 6/47 [00:26<03:38,  5.34s/it]
# bukit_view_secondary:   0%|                               | 0/4 [00:00<?, ?it/s]
# bukit_view_secondary:  25%|█████▊                 | 1/4 [00:00<00:02,  1.11it/s]
# bukit_view_secondary:  50%|███████████▌           | 2/4 [00:01<00:01,  1.08it/s]
# bukit_view_secondary:  75%|█████████████████▎     | 3/4 [00:02<00:01,  1.03s/it]
# bukit_view_secondary: 100%|███████████████████████| 4/4 [00:04<00:00,  1.14s/it]
# Schools:  15%|█████▏                             | 7/47 [00:30<03:20,  5.00s/it]
# bendemeer_secondary:   0%|                                | 0/4 [00:00<?, ?it/s]
# bendemeer_secondary:  25%|██████                  | 1/4 [00:00<00:02,  1.17it/s]
# bendemeer_secondary:  50%|████████████            | 2/4 [00:02<00:02,  1.12s/it]
# bendemeer_secondary:  75%|██████████████████      | 3/4 [00:03<00:01,  1.21s/it]
# bendemeer_secondary: 100%|████████████████████████| 4/4 [00:04<00:00,  1.22s/it]
# Schools:  17%|█████▉                             | 8/47 [00:35<03:11,  4.91s/it]
# raffles_girls':   0%|                                     | 0/4 [00:00<?, ?it/s]
# raffles_girls':  25%|███████▎                     | 1/4 [00:01<00:04,  1.62s/it]
# raffles_girls':  50%|██████████████▌              | 2/4 [00:02<00:02,  1.35s/it]
# raffles_girls':  75%|█████████████████████▊       | 3/4 [00:04<00:01,  1.45s/it]
# raffles_girls': 100%|█████████████████████████████| 4/4 [00:05<00:00,  1.21s/it]
# Schools:  19%|██████▋                            | 9/47 [00:40<03:10,  5.00s/it]
# fuhua_secondary:   0%|                                    | 0/4 [00:00<?, ?it/s]
# fuhua_secondary:  25%|███████                     | 1/4 [00:00<00:01,  1.87it/s]
# fuhua_secondary:  50%|██████████████              | 2/4 [00:00<00:00,  2.66it/s]
# fuhua_secondary:  75%|█████████████████████       | 3/4 [00:01<00:00,  2.65it/s]
# fuhua_secondary: 100%|████████████████████████████| 4/4 [00:01<00:00,  2.40it/s]
# Schools:  21%|███████▏                          | 10/47 [00:42<02:26,  3.97s/it]
# catholic_high:   0%|                                      | 0/4 [00:00<?, ?it/s]
# catholic_high:  25%|███████▌                      | 1/4 [00:01<00:04,  1.44s/it]
# catholic_high:  50%|███████████████               | 2/4 [00:03<00:03,  1.54s/it]
# catholic_high:  75%|██████████████████████▌       | 3/4 [00:04<00:01,  1.58s/it]
# catholic_high: 100%|██████████████████████████████| 4/4 [00:06<00:00,  1.70s/it]
# Schools:  23%|███████▉                          | 11/47 [00:48<02:51,  4.77s/it]
# chij_st_joseph's_convent:   0%|                           | 0/4 [00:00<?, ?it/s]
# chij_st_joseph's_convent:  25%|████▊              | 1/4 [00:01<00:04,  1.42s/it]
# chij_st_joseph's_convent:  50%|█████████▌         | 2/4 [00:03<00:03,  1.73s/it]
# chij_st_joseph's_convent:  75%|██████████████▎    | 3/4 [00:04<00:01,  1.67s/it]
# chij_st_joseph's_convent: 100%|███████████████████| 4/4 [00:06<00:00,  1.72s/it]
# Schools:  26%|████████▋                         | 12/47 [00:55<03:08,  5.37s/it]
# kent_ridge_secondary:   0%|                               | 0/4 [00:00<?, ?it/s]
# kent_ridge_secondary:  25%|█████▊                 | 1/4 [00:01<00:04,  1.47s/it]
# kent_ridge_secondary:  50%|███████████▌           | 2/4 [00:02<00:02,  1.45s/it]
# kent_ridge_secondary:  75%|█████████████████▎     | 3/4 [00:04<00:01,  1.40s/it]
# kent_ridge_secondary: 100%|███████████████████████| 4/4 [00:05<00:00,  1.25s/it]
# Schools:  28%|█████████▍                        | 13/47 [01:00<03:01,  5.34s/it]
# chung_cheng_high_main:   0%|                              | 0/6 [00:00<?, ?it/s]
# chung_cheng_high_main:  17%|███▋                  | 1/6 [00:01<00:06,  1.30s/it]
# chung_cheng_high_main:  33%|███████▎              | 2/6 [00:02<00:05,  1.42s/it]
# chung_cheng_high_main:  50%|███████████           | 3/6 [00:03<00:03,  1.23s/it]
# chung_cheng_high_main:  67%|██████████████▋       | 4/6 [00:04<00:02,  1.08s/it]
# chung_cheng_high_main:  83%|██████████████████▎   | 5/6 [00:05<00:01,  1.00s/it]
# chung_cheng_high_main: 100%|██████████████████████| 6/6 [00:07<00:00,  1.19s/it]
# Schools:  30%|██████████▏                       | 14/47 [01:07<03:13,  5.86s/it]
# christ_church_secondary:   0%|                            | 0/4 [00:00<?, ?it/s]
# christ_church_secondary:  25%|█████               | 1/4 [00:02<00:06,  2.20s/it]
# christ_church_secondary:  50%|██████████          | 2/4 [00:03<00:03,  1.51s/it]
# christ_church_secondary:  75%|███████████████     | 3/4 [00:04<00:01,  1.17s/it]
# christ_church_secondary: 100%|████████████████████| 4/4 [00:05<00:00,  1.14s/it]
# Schools:  32%|██████████▊                       | 15/47 [01:13<03:00,  5.63s/it]
# sports_school:   0%|                                      | 0/4 [00:00<?, ?it/s]
# sports_school:  25%|███████▌                      | 1/4 [00:00<00:01,  2.90it/s]
# sports_school:  50%|███████████████               | 2/4 [00:00<00:00,  2.24it/s]
# sports_school:  75%|██████████████████████▌       | 3/4 [00:01<00:00,  2.19it/s]
# sports_school: 100%|██████████████████████████████| 4/4 [00:01<00:00,  2.19it/s]
# Schools:  34%|███████████▌                      | 16/47 [01:14<02:18,  4.48s/it]
# whitley_secondary:   0%|                                  | 0/4 [00:00<?, ?it/s]
# whitley_secondary:  25%|██████▌                   | 1/4 [00:00<00:01,  2.02it/s]
# whitley_secondary:  50%|█████████████             | 2/4 [00:01<00:01,  1.42it/s]
# whitley_secondary:  75%|███████████████████▌      | 3/4 [00:01<00:00,  1.55it/s]
# whitley_secondary: 100%|██████████████████████████| 4/4 [00:02<00:00,  1.34it/s]
# Schools:  36%|████████████▎                     | 17/47 [01:17<01:59,  3.98s/it]
# chij_st_nicholas:   0%|                                   | 0/4 [00:00<?, ?it/s]
# chij_st_nicholas:  25%|██████▊                    | 1/4 [00:00<00:01,  1.67it/s]
# chij_st_nicholas:  50%|█████████████▌             | 2/4 [00:01<00:01,  1.38it/s]
# chij_st_nicholas:  75%|████████████████████▎      | 3/4 [00:02<00:00,  1.15it/s]
# chij_st_nicholas: 100%|███████████████████████████| 4/4 [00:03<00:00,  1.09it/s]
# Schools:  38%|█████████████                     | 18/47 [01:21<01:50,  3.82s/it]
# hai_sing_catholic_school:   0%|                           | 0/4 [00:00<?, ?it/s]
# hai_sing_catholic_school:  25%|████▊              | 1/4 [00:01<00:04,  1.63s/it]
# hai_sing_catholic_school:  50%|█████████▌         | 2/4 [00:02<00:02,  1.39s/it]
# hai_sing_catholic_school:  75%|██████████████▎    | 3/4 [00:04<00:01,  1.37s/it]
# hai_sing_catholic_school: 100%|███████████████████| 4/4 [00:05<00:00,  1.54s/it]
# Schools:  40%|█████████████▋                    | 19/47 [01:27<02:05,  4.47s/it]
# dunman_high:   0%|                                        | 0/5 [00:00<?, ?it/s]
# dunman_high:  20%|██████▍                         | 1/5 [00:01<00:05,  1.38s/it]
# dunman_high:  40%|████████████▊                   | 2/5 [00:03<00:04,  1.52s/it]
# dunman_high:  60%|███████████████████▏            | 3/5 [00:04<00:02,  1.29s/it]
# dunman_high:  80%|█████████████████████████▌      | 4/5 [00:05<00:01,  1.19s/it]
# dunman_high: 100%|████████████████████████████████| 5/5 [00:05<00:00,  1.09s/it]
# Schools:  43%|██████████████▍                   | 20/47 [01:33<02:12,  4.92s/it]
# woodlands_secondary:   0%|                                | 0/4 [00:00<?, ?it/s]
# woodlands_secondary:  25%|██████                  | 1/4 [00:00<00:01,  1.54it/s]
# woodlands_secondary:  50%|████████████            | 2/4 [00:01<00:01,  1.81it/s]
# woodlands_secondary:  75%|██████████████████      | 3/4 [00:01<00:00,  1.48it/s]
# woodlands_secondary: 100%|████████████████████████| 4/4 [00:02<00:00,  1.50it/s]
# Schools:  45%|███████████████▏                  | 21/47 [01:35<01:50,  4.23s/it]
# nan_chiau_high_school:   0%|                              | 0/4 [00:00<?, ?it/s]
# nan_chiau_high_school:  25%|█████▌                | 1/4 [00:01<00:04,  1.48s/it]
# nan_chiau_high_school:  50%|███████████           | 2/4 [00:02<00:02,  1.31s/it]
# nan_chiau_high_school:  75%|████████████████▌     | 3/4 [00:03<00:01,  1.26s/it]
# nan_chiau_high_school: 100%|██████████████████████| 4/4 [00:05<00:00,  1.46s/it]
# Schools:  47%|███████████████▉                  | 22/47 [01:41<01:56,  4.65s/it]
# northland_secondary:   0%|                                | 0/4 [00:00<?, ?it/s]
# northland_secondary:  25%|██████                  | 1/4 [00:01<00:03,  1.18s/it]
# northland_secondary:  50%|████████████            | 2/4 [00:02<00:02,  1.08s/it]
# northland_secondary:  75%|██████████████████      | 3/4 [00:02<00:00,  1.14it/s]
# northland_secondary: 100%|████████████████████████| 4/4 [00:03<00:00,  1.29it/s]
# Schools:  49%|████████████████▋                 | 23/47 [01:44<01:43,  4.29s/it]
# kuo_chuan_presbyterian_school:   0%|                      | 0/4 [00:00<?, ?it/s]
# kuo_chuan_presbyterian_school:  25%|███▌          | 1/4 [00:00<00:00,  4.95it/s]
# kuo_chuan_presbyterian_school:  50%|███████       | 2/4 [00:00<00:00,  3.16it/s]
# kuo_chuan_presbyterian_school:  75%|██████████▌   | 3/4 [00:01<00:00,  2.71it/s]
# kuo_chuan_presbyterian_school: 100%|██████████████| 4/4 [00:01<00:00,  2.47it/s]
# Schools:  51%|█████████████████▎                | 24/47 [01:46<01:19,  3.45s/it]
# st_margaret's_secondary:   0%|                            | 0/7 [00:00<?, ?it/s]
# st_margaret's_secondary:  14%|██▊                 | 1/7 [00:01<00:09,  1.56s/it]
# st_margaret's_secondary:  29%|█████▋              | 2/7 [00:02<00:07,  1.43s/it]
# st_margaret's_secondary:  43%|████████▌           | 3/7 [00:03<00:04,  1.10s/it]
# st_margaret's_secondary:  57%|███████████▍        | 4/7 [00:04<00:03,  1.11s/it]
# st_margaret's_secondary:  71%|██████████████▎     | 5/7 [00:05<00:02,  1.11s/it]
# st_margaret's_secondary:  86%|█████████████████▏  | 6/7 [00:06<00:01,  1.10s/it]
# st_margaret's_secondary: 100%|████████████████████| 7/7 [00:07<00:00,  1.03s/it]
# Schools:  53%|██████████████████                | 25/47 [01:54<01:44,  4.76s/it]
# woodgrove_secondary:   0%|                                | 0/6 [00:00<?, ?it/s]
# woodgrove_secondary:  17%|████                    | 1/6 [00:00<00:04,  1.12it/s]
# woodgrove_secondary:  33%|████████                | 2/6 [00:02<00:04,  1.13s/it]
# woodgrove_secondary:  50%|████████████            | 3/6 [00:03<00:03,  1.08s/it]
# woodgrove_secondary:  67%|████████████████        | 4/6 [00:04<00:02,  1.11s/it]
# woodgrove_secondary:  83%|████████████████████    | 5/6 [00:04<00:00,  1.24it/s]
# woodgrove_secondary: 100%|████████████████████████| 6/6 [00:06<00:00,  1.09s/it]
# Schools:  55%|██████████████████▊               | 26/47 [02:00<01:49,  5.22s/it]
# broadrick_secondary:   0%|                                | 0/4 [00:00<?, ?it/s]
# broadrick_secondary:  25%|██████                  | 1/4 [00:01<00:03,  1.13s/it]
# broadrick_secondary:  50%|████████████            | 2/4 [00:02<00:02,  1.36s/it]
# broadrick_secondary:  75%|██████████████████      | 3/4 [00:03<00:01,  1.29s/it]
# broadrick_secondary: 100%|████████████████████████| 4/4 [00:05<00:00,  1.41s/it]
# Schools:  57%|███████████████████▌              | 27/47 [02:05<01:45,  5.29s/it]
# yishun_secondary:   0%|                                   | 0/4 [00:00<?, ?it/s]
# yishun_secondary:  25%|██████▊                    | 1/4 [00:00<00:01,  1.62it/s]
# yishun_secondary:  50%|█████████████▌             | 2/4 [00:01<00:01,  1.96it/s]
# yishun_secondary:  75%|████████████████████▎      | 3/4 [00:01<00:00,  1.65it/s]
# yishun_secondary: 100%|███████████████████████████| 4/4 [00:02<00:00,  1.89it/s]
# Schools:  60%|████████████████████▎             | 28/47 [02:08<01:22,  4.36s/it]
# north_vista_secondary:   0%|                              | 0/4 [00:00<?, ?it/s]
# north_vista_secondary:  25%|█████▌                | 1/4 [00:01<00:03,  1.16s/it]
# north_vista_secondary:  50%|███████████           | 2/4 [00:02<00:02,  1.25s/it]
# north_vista_secondary:  75%|████████████████▌     | 3/4 [00:03<00:01,  1.09s/it]
# north_vista_secondary: 100%|██████████████████████| 4/4 [00:04<00:00,  1.00it/s]
# Schools:  62%|████████████████████▉             | 29/47 [02:12<01:17,  4.32s/it]
# yishun_town_secondary:   0%|                              | 0/4 [00:00<?, ?it/s]
# yishun_town_secondary:  25%|█████▌                | 1/4 [00:01<00:03,  1.03s/it]
# yishun_town_secondary:  50%|███████████           | 2/4 [00:01<00:01,  1.31it/s]
# yishun_town_secondary:  75%|████████████████▌     | 3/4 [00:02<00:00,  1.46it/s]
# yishun_town_secondary: 100%|██████████████████████| 4/4 [00:03<00:00,  1.31it/s]
# Schools:  64%|█████████████████████▋            | 30/47 [02:15<01:07,  3.95s/it]
# hillgrove_secondary:   0%|                                | 0/4 [00:00<?, ?it/s]
# hillgrove_secondary:  25%|██████                  | 1/4 [00:00<00:01,  2.35it/s]
# hillgrove_secondary:  50%|████████████            | 2/4 [00:00<00:00,  2.93it/s]
# hillgrove_secondary:  75%|██████████████████      | 3/4 [00:01<00:00,  2.72it/s]
# hillgrove_secondary: 100%|████████████████████████| 4/4 [00:01<00:00,  2.94it/s]
# Schools:  66%|██████████████████████▍           | 31/47 [02:16<00:50,  3.19s/it]
# guangyang_secondary:   0%|                                | 0/4 [00:00<?, ?it/s]
# guangyang_secondary:  25%|██████                  | 1/4 [00:00<00:01,  2.08it/s]
# guangyang_secondary:  50%|████████████            | 2/4 [00:00<00:00,  2.11it/s]
# guangyang_secondary:  75%|██████████████████      | 3/4 [00:01<00:00,  1.86it/s]
# guangyang_secondary: 100%|████████████████████████| 4/4 [00:02<00:00,  1.51it/s]
# Schools:  68%|███████████████████████▏          | 32/47 [02:19<00:44,  2.96s/it]
# swiss_cottage_secondary:   0%|                            | 0/4 [00:00<?, ?it/s]
# swiss_cottage_secondary:  25%|█████               | 1/4 [00:00<00:01,  1.78it/s]
# swiss_cottage_secondary:  50%|██████████          | 2/4 [00:00<00:00,  2.15it/s]
# swiss_cottage_secondary:  75%|███████████████     | 3/4 [00:01<00:00,  2.47it/s]
# swiss_cottage_secondary: 100%|████████████████████| 4/4 [00:01<00:00,  2.24it/s]
# Schools:  70%|███████████████████████▊          | 33/47 [02:20<00:36,  2.61s/it]
# manjusri_secondary:   0%|                                 | 0/4 [00:00<?, ?it/s]
# manjusri_secondary:  25%|██████▎                  | 1/4 [00:00<00:02,  1.32it/s]
# manjusri_secondary:  50%|████████████▌            | 2/4 [00:01<00:01,  1.05it/s]
# manjusri_secondary:  75%|██████████████████▊      | 3/4 [00:03<00:01,  1.11s/it]
# manjusri_secondary: 100%|█████████████████████████| 4/4 [00:03<00:00,  1.01it/s]
# Schools:  72%|████████████████████████▌         | 34/47 [02:24<00:39,  3.02s/it]
# boonlay_secondary:   0%|                                  | 0/4 [00:00<?, ?it/s]
# boonlay_secondary:  25%|██████▌                   | 1/4 [00:00<00:00,  3.08it/s]
# boonlay_secondary:  50%|█████████████             | 2/4 [00:00<00:00,  4.50it/s]
# boonlay_secondary:  75%|███████████████████▌      | 3/4 [00:00<00:00,  4.18it/s]
# boonlay_secondary: 100%|██████████████████████████| 4/4 [00:00<00:00,  4.86it/s]
# Schools:  74%|█████████████████████████▎        | 35/47 [02:25<00:28,  2.38s/it]
# assumption_english_secondary:   0%|                       | 0/4 [00:00<?, ?it/s]
# assumption_english_secondary:  25%|███▊           | 1/4 [00:00<00:01,  1.60it/s]
# assumption_english_secondary:  50%|███████▌       | 2/4 [00:01<00:01,  1.95it/s]
# assumption_english_secondary:  75%|███████████▎   | 3/4 [00:01<00:00,  1.44it/s]
# assumption_english_secondary: 100%|███████████████| 4/4 [00:02<00:00,  1.31it/s]
# Schools:  77%|██████████████████████████        | 36/47 [02:28<00:27,  2.52s/it]
# yio_chu_kang_secondary:   0%|                             | 0/3 [00:00<?, ?it/s]
# yio_chu_kang_secondary:  33%|███████              | 1/3 [00:00<00:00,  2.32it/s]
# yio_chu_kang_secondary:  67%|██████████████       | 2/3 [00:00<00:00,  2.90it/s]
# yio_chu_kang_secondary: 100%|█████████████████████| 3/3 [00:01<00:00,  2.96it/s]
# Schools:  79%|██████████████████████████▊       | 37/47 [02:29<00:20,  2.08s/it]
# bowen_secondary:   0%|                                    | 0/4 [00:00<?, ?it/s]
# bowen_secondary:  25%|███████                     | 1/4 [00:00<00:02,  1.07it/s]
# bowen_secondary:  50%|██████████████              | 2/4 [00:02<00:02,  1.12s/it]
# bowen_secondary:  75%|█████████████████████       | 3/4 [00:03<00:01,  1.17s/it]
# bowen_secondary: 100%|████████████████████████████| 4/4 [00:04<00:00,  1.33s/it]
# Schools:  81%|███████████████████████████▍      | 38/47 [02:34<00:26,  2.95s/it]
# evergreen_secondary:   0%|                                | 0/4 [00:00<?, ?it/s]
# evergreen_secondary:  25%|██████                  | 1/4 [00:00<00:01,  1.57it/s]
# evergreen_secondary:  50%|████████████            | 2/4 [00:01<00:01,  1.57it/s]
# evergreen_secondary:  75%|██████████████████      | 3/4 [00:01<00:00,  1.92it/s]
# evergreen_secondary: 100%|████████████████████████| 4/4 [00:01<00:00,  2.28it/s]
# Schools:  83%|████████████████████████████▏     | 39/47 [02:36<00:21,  2.66s/it]
# pasir_ris_secondary:   0%|                                | 0/4 [00:00<?, ?it/s]
# pasir_ris_secondary:  25%|██████                  | 1/4 [00:00<00:02,  1.03it/s]
# pasir_ris_secondary:  50%|████████████            | 2/4 [00:01<00:01,  1.17it/s]
# pasir_ris_secondary:  75%|██████████████████      | 3/4 [00:02<00:00,  1.06it/s]
# pasir_ris_secondary: 100%|████████████████████████| 4/4 [00:03<00:00,  1.10it/s]
# Schools:  85%|████████████████████████████▉     | 40/47 [02:40<00:20,  2.96s/it]
# outram_secondary:   0%|                                   | 0/4 [00:00<?, ?it/s]
# outram_secondary:  25%|██████▊                    | 1/4 [00:00<00:01,  2.12it/s]
# outram_secondary:  50%|█████████████▌             | 2/4 [00:00<00:00,  2.34it/s]
# outram_secondary:  75%|████████████████████▎      | 3/4 [00:01<00:00,  2.91it/s]
# outram_secondary: 100%|███████████████████████████| 4/4 [00:01<00:00,  3.10it/s]
# Schools:  87%|█████████████████████████████▋    | 41/47 [02:41<00:14,  2.49s/it]
# maris_stella:   0%|                                       | 0/4 [00:00<?, ?it/s]
# maris_stella:  25%|███████▊                       | 1/4 [00:01<00:03,  1.04s/it]
# maris_stella:  50%|███████████████▌               | 2/4 [00:02<00:02,  1.08s/it]
# maris_stella:  75%|███████████████████████▎       | 3/4 [00:03<00:01,  1.19s/it]
# maris_stella: 100%|███████████████████████████████| 4/4 [00:04<00:00,  1.24s/it]
# Schools:  89%|██████████████████████████████▍   | 42/47 [02:46<00:15,  3.18s/it]
# ngee_ann_secondary:   0%|                                 | 0/4 [00:00<?, ?it/s]
# ngee_ann_secondary:  25%|██████▎                  | 1/4 [00:00<00:01,  2.69it/s]
# ngee_ann_secondary:  50%|████████████▌            | 2/4 [00:00<00:00,  4.07it/s]
# ngee_ann_secondary:  75%|██████████████████▊      | 3/4 [00:00<00:00,  4.01it/s]
# ngee_ann_secondary: 100%|█████████████████████████| 4/4 [00:01<00:00,  3.47it/s]
# Schools:  91%|███████████████████████████████   | 43/47 [02:47<00:10,  2.57s/it]
# montfort_secondary:   0%|                                 | 0/4 [00:00<?, ?it/s]
# montfort_secondary:  25%|██████▎                  | 1/4 [00:00<00:02,  1.18it/s]
# montfort_secondary:  50%|████████████▌            | 2/4 [00:01<00:02,  1.02s/it]
# montfort_secondary:  75%|██████████████████▊      | 3/4 [00:03<00:01,  1.17s/it]
# montfort_secondary: 100%|█████████████████████████| 4/4 [00:04<00:00,  1.12s/it]
# Schools:  94%|███████████████████████████████▊  | 44/47 [02:52<00:09,  3.11s/it]
# greendale_secondary:   0%|                                | 0/6 [00:00<?, ?it/s]
# greendale_secondary:  17%|████                    | 1/6 [00:00<00:04,  1.11it/s]
# greendale_secondary:  33%|████████                | 2/6 [00:02<00:04,  1.06s/it]
# greendale_secondary:  50%|████████████            | 3/6 [00:03<00:03,  1.19s/it]
# greendale_secondary:  67%|████████████████        | 4/6 [00:04<00:02,  1.06s/it]
# greendale_secondary:  83%|████████████████████    | 5/6 [00:05<00:01,  1.02s/it]
# greendale_secondary: 100%|████████████████████████| 6/6 [00:06<00:00,  1.04it/s]
# Schools:  96%|████████████████████████████████▌ | 45/47 [02:58<00:08,  4.00s/it]
# edgefield_secondary:   0%|                                | 0/4 [00:00<?, ?it/s]
# edgefield_secondary:  25%|██████                  | 1/4 [00:00<00:01,  2.74it/s]
# edgefield_secondary:  50%|████████████            | 2/4 [00:00<00:00,  2.63it/s]
# edgefield_secondary:  75%|██████████████████      | 3/4 [00:00<00:00,  3.23it/s]
# edgefield_secondary: 100%|████████████████████████| 4/4 [00:01<00:00,  2.71it/s]
# Schools:  98%|█████████████████████████████████▎| 46/47 [02:59<00:03,  3.23s/it]
# seng_kang_secondary:   0%|                                | 0/4 [00:00<?, ?it/s]
# seng_kang_secondary:  25%|██████                  | 1/4 [00:00<00:02,  1.04it/s]
# seng_kang_secondary:  50%|████████████            | 2/4 [00:01<00:01,  1.20it/s]
# seng_kang_secondary:  75%|██████████████████      | 3/4 [00:02<00:00,  1.22it/s]
# seng_kang_secondary: 100%|████████████████████████| 4/4 [00:03<00:00,  1.34it/s]
# Schools: 100%|██████████████████████████████████| 47/47 [03:02<00:00,  3.89s/it]
# Finished scanning raw data.
# Devices in Term 1: 34674, Term 3: 46294
#
# Missing values summary:
# school_name_official    0
# gender                  1
# sch_psle                1
# level                   0
# dtype: int64
#
# User metadata files created: /Users/tdf/Downloads/user_metadata.xlsx, /Users/tdf/Downloads/user_metadata.csv

# %% [markdown]
# - Here, one row has missing gender and sch_psle values, indicating manual inspection is needed.

# %% [markdown]
# ## 13. Inspect Rows with Missing Values
#
# We extract the specific rows with missing values for review:

# %%
missing_rows = users_df[
    users_df['gender'].isna() | users_df['sch_psle'].isna()
]

missing_rows[
    ['device_name_actual', 'school_name', 'school_name_official', 'gender', 'sch_psle']
]
# Out:
#     device_name_actual              school_name  \
# 78                1822  methodist_girls'_school
#
#                    school_name_official  gender  sch_psle
# 78  Methodist Girls' School (Secondary)     NaN       NaN

# %% [markdown]
# ## 14. Manually Fill Missing Values
#
# Based on metadata inspection:
#
# - Methodist Girls’ School is a girls’ school, so `gender` = 1
# - PSLE cutoff group for this school is 1, so `sch_psle` = 1
#
# We update the row manually.
#
# After manual updates, confirm that there are no remaining missing values:

# %%
# Fill missing gender and PSLE for device 1822
users_df.loc[
    users_df['device_name_actual'] == 1822, 
    ['gender', 'sch_psle']
] = [1, 1]  # gender = 1 (girls), sch_psle = 1

# Check that missing values are gone
users_df[['school_name_official','gender','sch_psle','level']].isna().sum()
# Out:
# school_name_official    0
# gender                  0
# sch_psle                0
# level                   0
# dtype: int64

# %% [markdown]
# ## 15. Export Updated User Metadata
#
# Finally, we export the fully corrected and completed user metadata:

# %%
# Export updated user metadata
final_user_metadata = users_df[['device_name_actual','school_name_official','gender','sch_psle','level']]
final_user_metadata.to_excel(OUTPUT_FILE_XLSX, index=False)
final_user_metadata.to_csv(OUTPUT_FILE_CSV, index=False)

print(f"Updated user metadata files created: {OUTPUT_FILE_XLSX}, {OUTPUT_FILE_CSV}")
# Out:
# Updated user metadata files created: /Users/tdf/Downloads/user_metadata.xlsx, /Users/tdf/Downloads/user_metadata.csv

# %%
# Load the CSV
df = pd.read_csv('/Users/tdf/Downloads/user_metadata2.csv')

# Check for missing values in all columns
missing_summary = df.isna().sum()
print(missing_summary)
# Out:
# device_name_actual      0
# school_name_official    0
# gender                  0
# sch_psle                0
# level                   0
# dtype: int64
